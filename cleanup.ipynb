# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

pd.options.display.max_rows=1000

# %%
import googlemaps

#This won't work without your google geocode API Key
gmaps = googlemaps.Client(key='AIzaSyAyxtjGvhqikvRnu9LeqvjJGTCG8BJlCUo') # Alex's API key


def getCounty(location):
    county = np.NaN
    geocode_result = gmaps.geocode(location)
    if len(geocode_result)>0:
        counties = filter(lambda x: "administrative_area_level_2" in x["types"],geocode_result[0]["address_components"])
        if len(counties)>0:
            county = counties[0]["long_name"]
    return county

def getCity(location):
    city = np.NaN
    geocode_result = gmaps.geocode(location)
    if len(geocode_result)>0:
        cities = filter(lambda x: "locality" in x["types"],geocode_result[0]["address_components"])
        if len(cities)>0:
            city = cities[0]["long_name"]
    return city

# %%
d1 = pd.read_csv("Data/CSV/Amazon-Delivery-Station-Network-in-USA.csv")
d2 = pd.read_csv("Data/CSV/Amazon-Food-Distribution-Center-Network-in-USA.csv")
d3 = pd.read_csv("Data/CSV/Amazon-Fulfillment-Center-Network-in-USA.csv")
d4 = pd.read_csv("Data/CSV/Amazon-Inbound-Crossdock-Network-in-USA.csv")
d5 = pd.read_csv("Data/CSV/Amazon-Prime-Now-Network-in-USA.csv")
d6 = pd.read_csv("Data/CSV/Amazon-Sortation-Center-Network-in-USA.csv")

# %%
display(d1.head())
display(d2.head())
display(d3.head())
display(d4.head())
display(d5.head())
display(d6.head())
# Out:
#        ﻿State  Code                                           Location  \
# 0     Arizona  DPX1   500 S. 48th Street, Phoenix, Arizona, USA, 85034
# 1     Arizona  DPX3   550 E. Elliot Rd, Chandler . Arizona, USA, 85225
# 2  California  DSF1  990 Beecher St, San Leandro, California, USA, ...
# 3  California  DSF2  Candlestick Park Delivery Station, San Francis...
# 4  California  DSF3  1700 Montague Expy, San Jose, California, USA,...
#
#   Square\r\nFeet     Year\r\nOpened  \
# 0              -        May\r\n2015
# 1         91.200        May\r\n2017
# 2         42,400  September\r\n2013
# 3              -  September\r\n2013
# 4         25,800               2013
#
#                             Description of Operation
# 0  Delivery Station for Phoenix West Valley Co-lo...
# 1           Delivery Station for Phoenix East Valley
# 2                       Delivery Station for Oakland
# 3                      Delivery Station for Bay Area
# ...

# %%
#add a column for type to each one 
#combine into one oframe
d1["Type"]="Delivery Station"
d2["Type"]="Fresh"
d3["Type"]="Fulfillment"
d4["Type"]="Crossdock"
d5["Type"]="Now"
d6["Type"]="Sortation"

# %%
# The concat was getting messed up because the columns were different
good_columns = d1.columns.str.replace("\n"," ").str.replace("\r","")
d1.columns = good_columns
d2.columns = good_columns
d3.columns = good_columns
d4.columns = good_columns
d5.columns = good_columns
d6.columns = good_columns

# %%
d_concat = pd.concat([d1,d2,d3,d4,d5,d6])

# %%
print(d_concat.shape)
print (d_concat.shape)
d_concat.head()
# Out:
# (311, 7)
# (311, 7)
#        ﻿State  Code                                           Location  \
# 0     Arizona  DPX1   500 S. 48th Street, Phoenix, Arizona, USA, 85034
# 1     Arizona  DPX3   550 E. Elliot Rd, Chandler . Arizona, USA, 85225
# 2  California  DSF1  990 Beecher St, San Leandro, California, USA, ...
# 3  California  DSF2  Candlestick Park Delivery Station, San Francis...
# 4  California  DSF3  1700 Montague Expy, San Jose, California, USA,...
#
#   Square Feet        Year Opened  \
# 0           -        May\r\n2015
# 1      91.200        May\r\n2017
# 2      42,400  September\r\n2013
# 3           -  September\r\n2013
# 4      25,800               2013
#
#                             Description of Operation              Type
# 0  Delivery Station for Phoenix West Valley Co-lo...  Delivery Station
# 1           Delivery Station for Phoenix East Valley  Delivery Station
# 2                       Delivery Station for Oakland  Delivery Station
# ...

# %%
## Don't need this processing now

#get rid of weird new lines in column names
# d_reset = d_concat.reset_index(drop=True)

# good_cols = d_reset.columns.str.replace("\n"," ").str.replace("\r","")
# d_reset.columns=good_cols

d_reset = d_concat.reset_index(drop=True)

# %%
# Clean up entries
d_reset["Year Opened"] = d_reset["Year Opened"].str.replace('\r','')
d_reset["Year Opened"] = d_reset["Year Opened"].str.replace('\n',' ')
d_reset["Year Opened"] = d_reset["Year Opened"].str.strip()


d_reset["Location"] = d_reset["Location"].str.replace('\r','')
d_reset["Location"] = d_reset["Location"].str.replace('\n',' ')

d_reset["Description of Operation"] = d_reset["Description of Operation"].str.replace('\r','')
d_reset["Description of Operation"] = d_reset["Description of Operation"].str.replace('\n',' ')

d_reset["Code"] = d_reset["Code"].str.replace('\r','')
d_reset["Code"] = d_reset["Code"].str.replace('\n','')
d_reset["Code"] = d_reset["Code"].str.replace(' ','')

d_reset["Square Feet"] = d_reset["Square Feet"].str.replace('\n','')
d_reset["Square Feet"] = d_reset["Square Feet"].str.replace('\r','')
d_reset["Square Feet"] = d_reset["Square Feet"].str.replace('.','')
d_reset["Square Feet"] = d_reset["Square Feet"].str.replace(',','')
d_reset["Square Feet"] = d_reset["Square Feet"].replace('-',np.nan)

# %%
d_reset.iloc[73]["Square Feet"] = 1267100
d_reset.iloc[99]["Square Feet"] = 1035000
d_reset.iloc[220]["Year Opened"] = "September 2015"
d_reset.iloc[227]["Year Opened"] = "September 2015"

# %%
d_reset['County'] = np.vectorize(getCounty,otypes=[object])(d_reset["Location"])
d_reset['City'] = np.vectorize(getCity,otypes=[object])(d_reset["Location"])

# %%
#some of them are missing years, find out which 
display(d_reset[d_reset["Year Opened"].str.contains("\d{4}").fillna(False)==False])

#split out the year to new columns
d_reset["Year"] = d_reset["Year"].str.extract("(\d{4})",expand=False)
# Out:
#          ﻿State  Code                                           Location  \
# 50   California  LAX6  5119 District Blvd, Vernon, California. USA. 9...
# 242    Michigan  UMI1  Building 9, 19991 Brownstown Center Drive, Tre...
#
#     Square Feet Year Opened  \
# 50       121100         NaN
# 242         NaN         NaN
#
#                               Description of Operation   Type  \
# 50                                        Amazon.Fresh  Fresh
# 242  Prime Now Hub for Detroit Co-located in Sortat...    Now
#
#                  County                         City Year
# 50   Los Angeles County                       Vernon  NaN
# 242        Wayne County  Brownstown Charter Township  NaN

# %%
d_reset["Year"].value_counts()
# Out:
# 2016    68
# 2015    66
# 2017    50
# 2014    29
# 2013    26
# 2018    24
# 2012    10
# 2011     9
# 2010     8
# 2008     5
# 2007     4
# 2005     4
# 2019     2
# 2000     1
# 2006     1
# 1999     1
# 1997     1
# Name: Year, dtype: int64

# %%
#some of them are future openings
display(d_reset[d_reset["Year Opened"].str.contains("2019").fillna(False)].head())
display(d_reset[d_reset["Year Opened"].str.contains("2018").fillna(False)].head())
# Out:
#              ﻿State  Code                                           Location  \
# 97      Connecticut  BDL2  409 Washington Ave, North Haven. Connecticut, ...
# 163  North Carolina  CLT2  Macedonia Church Road. Kannapolis, North Carol...
#
#     Square Feet  Year Opened               Description of Operation  \
# 97       855000  Spring 2019  Sortable 1.800 associates to be hired
# 163     1000000         2019                     Large Non-Sortable
#
#             Type            County         City  Year
# 97   Fulfillment  New Haven County  North Haven  2019
# 163  Fulfillment   Cabarrus County      Concord  2019
#         ﻿State  Code                                           Location  \
# 63       Texas   NaN  Fallbrook Pines Business Park, Houston, Texas,...
# 69   Wisconsin  MKE7                         Burlington, Wisconsin, USA
# 82  California   NaN  Goodman Commerce Center, Antu-Galleano Ranch R...
# 86  California   NaN  Near Stockton Metro Airport, Stockton, Califor...
# ...

# %%
# Fixes almost all of the null county / city issues

# This is where candlestick park is
d_test.iloc[3]["County"] = "San Francisco County"
d_test.iloc[3]["City"] = "San Francisco"

# API got confused by '(Chealsea)'
d_test.iloc[28]["County"] = "Middlesex County"
d_test.iloc[28]["City"] = "Everett"

# Pretty sure this warehouse is in Manhattan
d_test.iloc[36]["County"] = "New York County"
d_test.iloc[36]["City"] = "New York City"

# API got confused by '(Chealsea)'
d_test.iloc[58]["County"] = "Middlesex County"
d_test.iloc[58]["City"] = "Everett"

# All of indianapolis is in Marion
d_test.iloc[116]["County"] = "Marion County"

# Bad address, but all of route 59 in aurora is in DuPage County
# http://www.businesswire.com/news/home/20161219006336/en/Amazon-Expand-Illinois-Fulfillment-Centers-1000-Full-Time
d_test.iloc[126]["County"] = "DuPage County"
d_test.iloc[126]["City"] = "Aurora"

# Warehouse is JUST outside the edge of Shepherdsville
d_test.iloc[140]["County"] = "Bullitt County"
d_test.iloc[140]["City"] = "Shepherdsville"

# Again, the warehouse is right on the border
d_test.iloc[142]["County"] = "Kenton County"
d_test.iloc[142]["City"] = "Erlanger"

# This one seems like it's technically in Denver, but the address is in Aurora.
# There's also two counties that cover Aurora, but the point is in Adams
d_test.iloc[229]["County"] = "Adams County"
d_test.iloc[229]["City"] = "Aurora"

# Warehouse is in Metro Air Park, near the Sacramento Airport
d_test.iloc[276]["County"] = "Sacramento County"
d_test.iloc[276]["City"] = "Sacramento"

# This is the sortation center that houses 229
d_test.iloc[277]["County"] = "Adams County"
d_test.iloc[277]["City"] = "Aurora"

# Hebron technically isn't a city, but it's definitely in Boone County
d_test.iloc[287]["County"] = "Boone County"
d_test.iloc[287]["City"] = "Hebron"

# Make city = New York City for anything in the 5 boroughs
d_test.iloc[162]["City"] = "New York City"
d_test.iloc[245]["City"] = "New York City"
d_test.iloc[246]["City"] = "New York City"

# Gouldsboro is a "village"
d_test.iloc[173]["City"] = "Gouldsboro"

# %%
# Baltimore and Chesapeake are not part of any counties (they're independent cities)
with pd.option_context('display.max_colwidth', 150,):
    display(d_reset[d_reset["County"].isnull()][["Code","Location","County","City","Type"]])
    display(d_reset[d_reset["City"].isnull()][["Code","Location","County","City","Type"]])
# Out:
#           Code                                                     Location  \
# 143  BWIO/BWI2  2010 Broening Highway, Baltimore, Maryland, USA, 21224-6027
# 240       UMD1     5001 Holabird Ave., Baltimore, Maryland, USA, 21224-6026
# 262       UVA2      804 Greenbrier Circle, Chesapeake, Virginia, USA, 23320
# 288  BWI5/UMD1     5001 Holabird Ave., Baltimore, Maryland, USA, 21224-6026
#
#     County        City         Type
# 143    NaN   Baltimore  Fulfillment
# 240    NaN   Baltimore          Now
# 262    NaN  Chesapeake          Now
# 288    NaN   Baltimore    Sortation
# Empty DataFrame
# Columns: [Code, Location, County, City, Type]
# Index: []

# %%
# Save cleaned data to file
d_reset.to_csv("Data/CSV/amazon_labelled_locations.csv",index=False)
