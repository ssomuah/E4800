# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %%
import googlemaps

#This won't work without your google geocode API Key
gmaps = googlemaps.Client(key='')


def getCounty(location):
    county = float("nan")
    geocode_result = gmaps.geocode(location)
    if len(geocode_result)>0:
        counties = filter(lambda x: "administrative_area_level_2" in x["types"],geocode_result[0]["address_components"])
        if len(counties)>0:
            county = counties[0]["long_name"]
    return county



def getCity(location):
    city = float("nan")
    geocode_result = gmaps.geocode(location)
    if len(geocode_result)>0:
        cities = filter(lambda x: "locality" in x["types"],geocode_result[0]["address_components"])
        if len(cities)>0:
            city = cities[0]["long_name"]
    return city

# %%
d1 = pd.read_csv("Data\CSV\Amazon-Delivery-Station-Network-in-USA.csv")
d2 = pd.read_csv("Data\CSV\Amazon-Food-Distribution-Center-Network-in-USA.csv")
d3 = pd.read_csv("Data\CSV\Amazon-Fulfillment-Center-Network-in-USA.csv")
d4 = pd.read_csv("Data\CSV\Amazon-Inbound-Crossdock-Network-in-USA.csv")
d5 = pd.read_csv("Data\CSV\Amazon-Prime-Now-Network-in-USA.csv")
d6 = pd.read_csv("Data\CSV\Amazon-Sortation-Center-Network-in-USA.csv")

# %%
display(d1.head())
display(d2.head())
display(d3.head())
display(d4.head())
display(d5.head())
display(d6.head())
# Out:
#         State  Code                                           Location  \
# 0     Arizona  DPX1   500 S. 48th Street, Phoenix, Arizona, USA, 85034
# 1     Arizona  DPX3   550 E. Elliot Rd, Chandler . Arizona, USA, 85225
# 2  California  DSF1  990 Beecher St, San Leandro, California, USA, ...
# 3  California  DSF2  Candlestick Park Delivery Station, San Francis...
# 4  California  DSF3  1700 Montague Expy, San Jose, California, USA,...
#
#   Square\nFeet     Year\nOpened  \
# 0            -        May\n2015
# 1       91.200        May\n2017
# 2       42,400  September\n2013
# 3            -  September\n2013
# 4       25,800             2013
#
#                             Description of Operation
# 0  Delivery Station for Phoenix West Valley Co-lo...
# 1           Delivery Station for Phoenix East Valley
# 2                       Delivery Station for Oakland
# 3                      Delivery Station for Bay Area
# 4                      Delivery Station for San Jose
#         State        Code                                           Location  \
# 0  California  ONT4/ ONT7  2020 E. Central Ave., Building 4, San Bernardi...
# 1  California        LAX6  5119 District Blvd, Vernon, California. USA. 9...
# 2  California        OAK6  1555 N. Chrisman Rd., Tracy, California, USA, ...
# 3  California        OAK7  38811 Cherry Street, Newark. California, USA, ...
# 4    Colorado        DEN6  Crossroads Commerce Park, Building 2, 480 E. 5...
#
#   Square\nFeet    Year\nOpened  \
# 0      514,600   October\n2013
# 1      121,100             NaN
# 2            -   October\n2013
# 3            -  November\n2014
# 4      290,700            2017
#
#                             Description of Operation
# 0  Building 4 connects to Building 3 ONT4 is Amaz...
# 1                                       Amazon.Fresh
# 2  OAK6 is Amazon.Fresh for the San Francisco Bay...
# 3       OAK7 is Amazon Pantry Co-located within OAKS
# 4  To be confirmed as an Amazon.Fresh Distributio...
#      State        Code                                           Location  \
# 0  Arizona        PHX3  6835 West Buckeye Road, Phoenix, Arizona, USA,...
# 1  Arizona        PHX5  16920 W. Commerce Dr. , Goodyear, Arizona, USA...
# 2  Arizona  PHX6/ TFC1  4750 & 5050 West Mohave Street, Phoenix, Arizo...
# 3  Arizona  PHX7/ PHX8  800 N. 75th Ave, Phoenix,\nArizona, USA, 85043...
# 4  Arizona        PHX9      777 S 79th Ave, Tolleson, Arizona, USA, 85353
#
#     Square\nFeet     Year\nOpened  \
# 0      1,009,400  September\n2007
# 1        820,400       June\n2008
# 2      1,205,600    October\n2010
# 3  267,\n100 1 .  September\n2011
# 4        580,100    October\n2015
#
#                             Description of Operation
# 0  Large Sortable & Apparel Fulfillment Center. O...
# 1  Large Non-Sortable Fulfillment Center.\nOrigin...
# 2  Large Sortable Fulfillment Center in one half ...
# 3  PHX7 is Large Non-Sortable\nPHX8 is a Sortatio...
# 4                              PHX9 is a Seasonal FC
#             State        Code  \
# 0      California        ONT8
# 1        Illinois        MDW2
# 2        Kentucky        CVG3
# 3      New Jersey  ABE8/ TTN1
# 4  North Carolina        CLT2
#
#                                             Location Square\nFeet  \
# 0  24300 Nandina Ave, Moreno Valley, California, ...      769,300
# 1  250 Emerald Drive/401 E. Layaway Rd, Joliet, I...      475,100
# 2     3680 Langley Dr., Hebron, Kentucky, USA, 41048      711,400
# 3  309 Cedar Lane, Florence, New Jersey, USA, 085...      613,900
# 4  10240 Old Dowd Road, Mecklenburg, Charlotte, N...      397,800
#
#       Year\nOpened                           Description of Operation
# 0     August\n2014                           Inbound Cross Dock (IXD)
# 1    October\n2015                           Inbound Cross Dock (IXD)
# 2       July\n2007                           Inbound Cross Dock (IXD)
# 3  September\n2016                           Inbound Cross Dock (IXD)
# 4    October\n2016  Inbound Cross Dock (IXD)\nAmazon Prime Air Ser...
#         State        Code                                           Location  \
# 0     Arizona  UAZ1/ DPX1        500 S 48th St, Phoenix, Arizona, USA, 85034
# 1  California        UCA1  888 Tennessee Street, San Francisco, Californi...
# 2  California        UCA2  2400 Marine Ave, Redondo Beach, California, US...
# 3  California        UCA3  11800 W Olympic Blvd, Santa Monica. California...
# 4  California        UCA4     2006 McGaw Ave, Irvine, California, USA, 92614
#
#   Square\nFeet   Year\nOpened                    Description of Operation
# 0       59,900      May\n2015  Prime Now Hub/Delivery Station for Phoenix
# 1       39,000  October\n2016             Prime Now Hub for San Francisco
# 2       50,000           2015               Prime Now Hub for Los Angeles
# 3       28,800   September-15              Prime Now Hub for Santa Monica
# 4       45,300           2015                Prime Now Hub for Irvine, CA
#         State  Code                                           Location  \
# 0     Alabama  MOBS   6735 Trippel Road, Theodore, Alabama, USA, 36619
# 1     Arizona  PHX8  800 N. 75th Ave, Phoenix.\nArizona. USA, 85043...
# 2  California  OAKS  38811 Cherry Street, Newark, California, USA, ...
# 3  California  ONTS  2020 E. Central Ave., San Bernardino, Californ...
# 4  California  LAXS  6400 Valley View Street, Bueno Park, Californi...
#
#   Square\nFeet    Year\nOpened  \
# 0      362,000   October\n2017
# 1            -   October\n2010
# 2      574,600  November\n2014
# 3            -   October\n2013
# 4      238,300         Q3 2017
#
#                             Description of Operation
# 0                    Sortation Center for Mobile, AL
# 1           PHX8 Square Feet is included within PHX7
# 2  OAKS is a Sortation Center to service the San ...
# 3        Sortation Center for the Los Angeles region
# 4        Sortation Center for the Los Angeles region

# %%
#add a column for type to each one 
#combine into one oframe
d1["Type"]="Delivery Station"
d2["Type"]="Fresh"
d3["Type"]="Fulfillment"
d4["Type"]="Crossdock"
d5["Type"]="Now"
d6["Type"]="Sortation"

# %%
d_concat = pd.concat([d1,d2,d3,d4,d5,d6])

# %%
print(d_concat.shape)
print (d_concat.shape)
d_concat.head()
# Out:
# (311, 7)
# (311, 7)
#         State  Code                                           Location  \
# 0     Arizona  DPX1   500 S. 48th Street, Phoenix, Arizona, USA, 85034
# 1     Arizona  DPX3   550 E. Elliot Rd, Chandler . Arizona, USA, 85225
# 2  California  DSF1  990 Beecher St, San Leandro, California, USA, ...
# 3  California  DSF2  Candlestick Park Delivery Station, San Francis...
# 4  California  DSF3  1700 Montague Expy, San Jose, California, USA,...
#
#   Square\nFeet     Year\nOpened  \
# 0            -        May\n2015
# 1       91.200        May\n2017
# 2       42,400  September\n2013
# 3            -  September\n2013
# 4       25,800             2013
#
#                             Description of Operation              Type
# 0  Delivery Station for Phoenix West Valley Co-lo...  Delivery Station
# 1           Delivery Station for Phoenix East Valley  Delivery Station
# 2                       Delivery Station for Oakland  Delivery Station
# 3                      Delivery Station for Bay Area  Delivery Station
# 4                      Delivery Station for San Jose  Delivery Station

# %%
#get rid of weird new lines in column names
d_reset = d_concat.reset_index(drop=True)

good_cols = d_reset.columns.str.replace("\n"," ")
d_reset.columns=good_cols

# %%
d_reset.head()
# Out:
#         State  Code                                           Location  \
# 0     Arizona  DPX1   500 S. 48th Street, Phoenix, Arizona, USA, 85034
# 1     Arizona  DPX3   550 E. Elliot Rd, Chandler . Arizona, USA, 85225
# 2  California  DSF1  990 Beecher St, San Leandro, California, USA, ...
# 3  California  DSF2  Candlestick Park Delivery Station, San Francis...
# 4  California  DSF3  1700 Montague Expy, San Jose, California, USA,...
#
#   Square Feet      Year Opened  \
# 0           -        May\n2015
# 1      91.200        May\n2017
# 2      42,400  September\n2013
# 3           -  September\n2013
# 4      25,800             2013
#
#                             Description of Operation              Type
# 0  Delivery Station for Phoenix West Valley Co-lo...  Delivery Station
# 1           Delivery Station for Phoenix East Valley  Delivery Station
# 2                       Delivery Station for Oakland  Delivery Station
# 3                      Delivery Station for Bay Area  Delivery Station
# 4                      Delivery Station for San Jose  Delivery Station

# %%
d_reset.columns
# Out:
# Index([u'State', u'Code', u'Location', u'Square Feet', u'Year Opened',
#        u'Description of Operation', u'Type'],
#       dtype='object')

# %%
#replace the \ns in year and then figure out how large a date range we need
#do the same thing for Location 
d_reset["Year Opened"]=d_reset["Year Opened"].str.replace("\n", " ")
d_reset["Location"]=d_reset["Location"].str.replace("\n", " ")

# %%
#some of them are missing years, find out which 
d_reset[d_reset["Year Opened"].str.contains("\d{4}").fillna(False)==False]
# Out:
#           State  Code                                           Location  \
# 50   California  LAX6  5119 District Blvd, Vernon, California. USA. 9...
# 220  California  UCA3  11800 W Olympic Blvd, Santa Monica. California...
# 227  California  HCA3  3334 North San Fernando Road, Building E, Los ...
# 242    Michigan  UMI1  Building 9, 19991 Brownstown Center Drive, Tre...
#
#     Square Feet   Year Opened  \
# 50      121,100           NaN
# 220      28,800  September-15
# 227      58,900  September-15
# 242           -           NaN
#
#                               Description of Operation   Type
# 50                                        Amazon.Fresh  Fresh
# 220                     Prime Now Hub for Santa Monica    Now
# 227                Prime Now Hub for North Los Angeles    Now
# 242  Prime Now Hub for Detroit Co-located in Sortat...    Now

# %%
d_reset['County'] = np.vectorize(getCounty)(d_reset["Location"])
d_reset['City'] = np.vectorize(getCity)(d_reset["Location"])
# Out:
# C:\Users\akwes\Anaconda2\envs\cappy\lib\site-packages\numpy\lib\function_base.py:2810: RuntimeWarning: invalid value encountered in getCounty (vectorized)
#   outputs = ufunc(*inputs)
# C:\Users\akwes\Anaconda2\envs\cappy\lib\site-packages\numpy\lib\function_base.py:2810: RuntimeWarning: invalid value encountered in getCity (vectorized)
#   outputs = ufunc(*inputs)

# %%
#split out the year to new columns
d_reset["Year"] = d_reset["Year Opened"].str.extract("(\d{4})",expand=False).astype(int,errors="ignore")

# %%
years = d_reset["Year Opened"].str.extract("(\d{4})",expand=False).sort_values()

# %%
print (years.value_counts())
# Out:
# 2016    68
# 2015    64
# 2017    50
# 2014    29
# 2013    26
# 2018    24
# 2012    10
# 2011     9
# 2010     8
# 2008     5
# 2005     4
# 2007     4
# 2019     2
# 2000     1
# 2006     1
# 1999     1
# 1997     1
# Name: Year Opened, dtype: int64

# %%
#some of them are future openings
d_reset[d_reset["Year Opened"].str.contains("2019").fillna(False)]
# Out:
#               State  Code                                           Location  \
# 97      Connecticut  BDL2  409 Washington Ave, North Haven. Connecticut, ...
# 163  North Carolina  CLT2  Macedonia Church Road. Kannapolis, North Carol...
#
#     Square Feet  Year Opened                Description of Operation  \
# 97      855,000  Spring 2019  Sortable\n1.800 associates to be hired
# 163   1,000,000         2019                      Large Non-Sortable
#
#             Type            County         City  Year
# 97   Fulfillment  New Haven County  North Haven  2019
# 163  Fulfillment   Cabarrus County      Concord  2019

# %%
#save output
d_reset.to_csv("amazon_labelled_locations.csv",index=False)

# %%
#what kind of nulls do we still have
#we probably don't care about null codes
#Some of the addresses that failed lookup can be fixed manually

d_reset[d_reset.isnull().any(axis=1)]
# Out:
#           State  Code                                           Location  \
# 32     Missouri   NaN  Building 4, 441 Hazelwood Logistics Center Dri...
# 46     Virginia   NaN  4101Carolina Avenue, Richmond, Virginia, USA, ...
# 50   California  LAX6  5119 District Blvd, Vernon, California. USA. 9...
# 61     New York   NaN  201 Grumman Rd. W. , Bethpage, New York, USA, ...
# 63        Texas   NaN  Fallbrook Pines Business Park near the interse...
# 82   California   NaN  Goodman Commerce Center, Antu-Galleano Ranch R...
# 86   California   NaN  Near Stockton Metro Airport, Stockton, Califor...
# 93   California   NaN  South Orange Avenue near Central Avenue, Fresn...
# 126    Illinois   NaN             Route 59, Aurora, Illinois, USA, 60504
# 129      Kansas  MCI7  27200 West 157th Street, Johnson (New Century)...
# 162    New York   NaN  656 Gulf Ave, Staten Island, New York, USA, 10314
# 167        Ohio   NaN                           Monroe, Ohio, USA, 45036
# 205    Virginia   NaN  281 Woodbine RoadClear Brook, Virginia, USA, 2...
# 220  California  UCA3  11800 W Olympic Blvd, Santa Monica. California...
# 227  California  HCA3  3334 North San Fernando Road, Building E, Los ...
# 228  California   NaN  2403 W. Louise Ave., Manteca. California, USA,...
# 229    Colorado  UCO1  19799 E. 36th Avenue, Majestic Commercenter Bu...
# 242    Michigan  UMI1  Building 9, 19991 Brownstown Center Drive, Tre...
# 246    New York   NaN  850 Third Ave., Liberty View Industrial Plaza,...
# 276  California   NaN  Airport Hub Sortation Center, Sacramento, Cali...
# 287    Kentucky   NaN  Airport Hub Sortation Center. Hebron, Kentucky...
# 299        Ohio   NaN                           Monroe, Ohio, USA, 45036
#
#     Square Feet     Year Opened  \
# 32      100,000         Q3 2017
# 46       45,000  September 2017
# 50      121,100             NaN
# 61      161,400        Q4 2016
# 63      197,900            2018
# 82    1,000,000            2018
# 86      600,000            2018
# 93      855,000       July 2018
# 126     400,000            2018
# 129     446,500         Q4 2016
# 162     855,000         Q3 2018
# 167   1,000.000            2018
# 205   1,061,000            2018
# 220      28,800    September-15
# 227      58,900    September-15
# 228      91.100            2017
# 229         NaN       June 2016
# 242           -             NaN
# 246           -   December 2015
# 276      40.000         Q4 2017
# 287   3,350,000    October 2018
# 299     300.000            2018
#
#                               Description of Operation              Type  \
# 32                      Delivery Station for St. Louis  Delivery Station
# 46                    Delivery Station for Richmond VA  Delivery Station
# 50                                        Amazon.Fresh             Fresh
# 61   Amazon Pantry (FDFC)\nFormerly a Goya Distribu...             Fresh
# 63                    Amazon.Fresh Distribution Center             Fresh
# 82                                  Large Non-Sortable       Fulfillment
# 86                  Large Non-Sortable 1000 associates       Fulfillment
# 93                                            Sortable       Fulfillment
# 126                                 Large Non-Sortable       Fulfillment
# 129                                                NaN       Fulfillment
# 162                                     Small Sortable       Fulfillment
# 167      Large Non-Sortable\nNo ETA date announced yet       Fulfillment
# 205  Large Non-Sortable\nShips larger packages that...       Fulfillment
# 220                     Prime Now Hub for Santa Monica               Now
# 227                Prime Now Hub for North Los Angeles               Now
# 228  Prime Now Hub/Delivery Station for Stockton. M...               Now
# 229  Prime Now Hub for Denver\nLocated within Sorta...               Now
# 242  Prime Now Hub for Detroit Co-located in Sortat...               Now
# 246                         Prime Now Hub for Brooklyn               Now
# 276                   Air Sortation Hub for Sacramento         Sortation
# 287  New AirHub being constructed.\nWill include a ...         Sortation
# 299  We believe this to be a Sortation Center for t...         Sortation
#
#                  County                         City  Year
# 32     St. Louis County                    Hazelwood  2017
# 46       Henrico County                     Richmond  2017
# 50   Los Angeles County                       Vernon   NaN
# 61        Nassau County                     Bethpage  2016
# 63                  nan                          nan  2018
# 82     Riverside County                     Eastvale  2018
# 86   San Joaquin County                     Stockton  2018
# 93        Fresno County                       Fresno  2018
# 126                 nan                          nan  2018
# 129      Johnson County                  New Century  2016
# 162     Richmond County                          nan  2018
# 167       Butler County                       Monroe  2018
# 205    Frederick County                  Clear Brook  2018
# 220  Los Angeles County                  Los Angeles   NaN
# 227  Los Angeles County                  Los Angeles   NaN
# 228  San Joaquin County                      Manteca  2017
# 229                 nan                          nan  2016
# 242        Wayne County  Brownstown Charter Township   NaN
# 246        Kings County                          nan  2015
# 276                 nan                          nan  2017
# 287                 nan                          nan  2018
# 299       Butler County                       Monroe  2018
